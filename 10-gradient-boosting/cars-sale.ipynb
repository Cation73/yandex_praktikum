# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Сервис по продаже автомобилей с пробегом «Не бит, не крашен» разрабатывает приложение для привлечения новых клиентов. В нём можно быстро узнать рыночную стоимость своего автомобиля. В вашем распоряжении исторические данные: технические характеристики, комплектации и цены автомобилей. Вам нужно построить модель для определения стоимости.
#
# Заказчику важны:
#
# - качество предсказания;
# - скорость предсказания;
# - время обучения.

# %% [markdown]
# # 1. Подготовка данных

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_val_score
from catboost import CatBoostRegressor
import lightgbm as lgb
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import mean_squared_error
import xgboost as xgb
import time
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/datasets/autos.csv')

# %%
df.head()
# Out:
#            DateCrawled  Price VehicleType  RegistrationYear Gearbox  Power  \
# 0  2016-03-24 11:52:17    480         NaN              1993  manual      0
# 1  2016-03-24 10:58:45  18300       coupe              2011  manual    190
# 2  2016-03-14 12:52:21   9800         suv              2004    auto    163
# 3  2016-03-17 16:54:04   1500       small              2001  manual     75
# 4  2016-03-31 17:25:20   3600       small              2008  manual     69
#
#    Model  Kilometer  RegistrationMonth  FuelType       Brand NotRepaired  \
# 0   golf     150000                  0    petrol  volkswagen         NaN
# 1    NaN     125000                  5  gasoline        audi         yes
# 2  grand     125000                  8  gasoline        jeep         NaN
# 3   golf     150000                  6    petrol  volkswagen          no
# 4  fabia      90000                  7  gasoline       skoda          no
#
#            DateCreated  NumberOfPictures  PostalCode             LastSeen
# 0  2016-03-24 00:00:00                 0       70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00                 0       66954  2016-04-07 01:46:50
# 2  2016-03-14 00:00:00                 0       90480  2016-04-05 12:47:46
# 3  2016-03-17 00:00:00                 0       91074  2016-03-17 17:40:17
# 4  2016-03-31 00:00:00                 0       60437  2016-04-06 10:17:21

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354369 entries, 0 to 354368
# Data columns (total 16 columns):
# DateCrawled          354369 non-null object
# Price                354369 non-null int64
# VehicleType          316879 non-null object
# RegistrationYear     354369 non-null int64
# Gearbox              334536 non-null object
# Power                354369 non-null int64
# Model                334664 non-null object
# Kilometer            354369 non-null int64
# RegistrationMonth    354369 non-null int64
# FuelType             321474 non-null object
# Brand                354369 non-null object
# NotRepaired          283215 non-null object
# DateCreated          354369 non-null object
# NumberOfPictures     354369 non-null int64
# PostalCode           354369 non-null int64
# LastSeen             354369 non-null object
# dtypes: int64(7), object(9)
# memory usage: 43.3+ MB

# %%
df.describe()
# Out:
#                Price  RegistrationYear          Power      Kilometer  \
# count  354369.000000     354369.000000  354369.000000  354369.000000
# mean     4416.656776       2004.234448     110.094337  128211.172535
# std      4514.158514         90.227958     189.850405   37905.341530
# min         0.000000       1000.000000       0.000000    5000.000000
# 25%      1050.000000       1999.000000      69.000000  125000.000000
# 50%      2700.000000       2003.000000     105.000000  150000.000000
# 75%      6400.000000       2008.000000     143.000000  150000.000000
# max     20000.000000       9999.000000   20000.000000  150000.000000
#
#        RegistrationMonth  NumberOfPictures     PostalCode
# count      354369.000000          354369.0  354369.000000
# mean            5.714645               0.0   50508.689087
# std             3.726421               0.0   25783.096248
# min             0.000000               0.0    1067.000000
# 25%             3.000000               0.0   30165.000000
# 50%             6.000000               0.0   49413.000000
# 75%             9.000000               0.0   71083.000000
# max            12.000000               0.0   99998.000000

# %%
# Удалим столбцы, которые, скорее всего, не имеют силы в предсказании
df = df.drop(columns = ['DateCrawled', 'DateCreated', 'LastSeen', 'NumberOfPictures'])

# %%
# В данном столбце можно предположить, что если данные отсутствуют, значит ремонтных работ не проводилось, поэтому сделаем замену
for i in ['NotRepaired', 'VehicleType', 'Model', 'FuelType', 'Gearbox']:
    df[i] = df[i].fillna(0)
    df[i] = df[i].replace(0, 'unspecified')

df.head()
# Out:
#    Price  VehicleType  RegistrationYear Gearbox  Power        Model  \
# 0    480  unspecified              1993  manual      0         golf
# 1  18300        coupe              2011  manual    190  unspecified
# 2   9800          suv              2004    auto    163        grand
# 3   1500        small              2001  manual     75         golf
# 4   3600        small              2008  manual     69        fabia
#
#    Kilometer  RegistrationMonth  FuelType       Brand  NotRepaired  PostalCode
# 0     150000                  0    petrol  volkswagen  unspecified       70435
# 1     125000                  5  gasoline        audi          yes       66954
# 2     125000                  8  gasoline        jeep  unspecified       90480
# 3     150000                  6    petrol  volkswagen           no       91074
# 4      90000                  7  gasoline       skoda           no       60437

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354369 entries, 0 to 354368
# Data columns (total 12 columns):
# Price                354369 non-null int64
# VehicleType          354369 non-null object
# RegistrationYear     354369 non-null int64
# Gearbox              354369 non-null object
# Power                354369 non-null int64
# Model                354369 non-null object
# Kilometer            354369 non-null int64
# RegistrationMonth    354369 non-null int64
# FuelType             354369 non-null object
# Brand                354369 non-null object
# NotRepaired          354369 non-null object
# PostalCode           354369 non-null int64
# dtypes: int64(6), object(6)
# memory usage: 32.4+ MB

# %%
# Перекодируем в численные значения
df = df.apply(LabelEncoder().fit_transform)

# %%
# Прямое кодирование
df = pd.get_dummies(df, columns = ['NotRepaired', 'Gearbox'], drop_first = True)

# %%
# Разбивка датасета на тренировочную, валидационную и тестовую выборки
df_train, df_test = train_test_split(df, test_size=0.2, random_state=12345)
df_train, df_valid = train_test_split(df_train, test_size=0.25, random_state=12345)
features_train = df_train.drop(['Price'], axis=1)
target_train = df_train['Price']
features_valid = df_valid.drop(['Price'], axis=1)
target_valid = df_valid['Price']
features_test = df_test.drop(['Price'], axis=1)
target_test = df_test['Price']

# %% [markdown]
# # 2. Обучение моделей

# %% [markdown]
# ### CatBoost

# %%
model_cb = CatBoostRegressor(random_state = 12345, iterations = 300)
parameters_cb = {'depth': range(6, 11),
                 'learning_rate': [0.001, 0.01, 0.05, 0.1]}
search_cb = RandomizedSearchCV(model_cb, parameters_cb, cv = 5, n_jobs = -1, random_state = 12345)
search_cb.fit(features_train, target_train, verbose = 100)
best_cb = search_cb.best_estimator_
predict_cb_valid = best_cb.predict(features_valid)
rmse_cb_valid = mean_squared_error(target_valid, predict_cb_valid)**0.5
print('Качество модели CatBoost на валидационной выборке (корень из средней квадратичной ошибки):', rmse_cb_valid)
# Out:
# 0:	learn: 956.3999854	total: 216ms	remaining: 1m 4s
# 100:	learn: 585.2447044	total: 19.9s	remaining: 39.1s
# 200:	learn: 481.4648103	total: 39.1s	remaining: 19.3s
# 299:	learn: 446.0565172	total: 58.2s	remaining: 0us
# 0:	learn: 956.0195231	total: 173ms	remaining: 51.8s
# 100:	learn: 585.4519262	total: 20.1s	remaining: 39.6s
# 200:	learn: 481.9085961	total: 39.8s	remaining: 19.6s
# 299:	learn: 446.6376610	total: 58.2s	remaining: 0us
# 0:	learn: 956.9826825	total: 68.2ms	remaining: 20.4s
# 100:	learn: 585.7202549	total: 19.4s	remaining: 38.2s
# 200:	learn: 481.4428473	total: 38s	remaining: 18.7s
# 299:	learn: 446.2186321	total: 57.8s	remaining: 0us
# 0:	learn: 957.1410409	total: 143ms	remaining: 42.8s
# 100:	learn: 585.0717375	total: 19.1s	remaining: 37.6s
# 200:	learn: 480.3307249	total: 37.7s	remaining: 18.6s
# 299:	learn: 444.7134037	total: 57.4s	remaining: 0us
# 0:	learn: 956.0642499	total: 89ms	remaining: 26.6s
# 100:	learn: 585.6328271	total: 18.9s	remaining: 37.3s
# 200:	learn: 481.5039573	total: 37.5s	remaining: 18.5s
# 299:	learn: 446.0768574	total: 55.8s	remaining: 0us
# 0:	learn: 962.3002628	total: 71.8ms	remaining: 21.5s
# 100:	learn: 902.0531849	total: 17s	remaining: 33.5s
# 200:	learn: 848.8566339	total: 34.6s	remaining: 17.1s
# 299:	learn: 802.2946175	total: 51.8s	remaining: 0us
# 0:	learn: 961.9065676	total: 42.8ms	remaining: 12.8s
# 100:	learn: 901.7555547	total: 17.4s	remaining: 34.2s
# 200:	learn: 848.5166547	total: 34.9s	remaining: 17.2s
# 299:	learn: 802.0470741	total: 51.7s	remaining: 0us
# 0:	learn: 962.9060260	total: 88.5ms	remaining: 26.5s
# 100:	learn: 902.6214008	total: 16.8s	remaining: 33.2s
# 200:	learn: 849.2979623	total: 33.7s	remaining: 16.6s
# 299:	learn: 802.7299134	total: 50.5s	remaining: 0us
# 0:	learn: 963.0612790	total: 23.7ms	remaining: 7.09s
# 100:	learn: 902.6414965	total: 16.9s	remaining: 33.2s
# 200:	learn: 849.1144489	total: 33.6s	remaining: 16.5s
# 299:	learn: 802.3462969	total: 50.1s	remaining: 0us
# 0:	learn: 961.9902110	total: 96.6ms	remaining: 28.9s
# 100:	learn: 901.7910728	total: 16.8s	remaining: 33.2s
# 200:	learn: 848.5916205	total: 33.5s	remaining: 16.5s
# 299:	learn: 802.0354442	total: 49.9s	remaining: 0us
# 0:	learn: 962.2842542	total: 168ms	remaining: 50.3s
# 100:	learn: 899.9200732	total: 23.3s	remaining: 45.9s
# 200:	learn: 844.5269827	total: 46.5s	remaining: 22.9s
# 299:	learn: 796.0412996	total: 1m 9s	remaining: 0us
# 0:	learn: 961.8904125	total: 189ms	remaining: 56.5s
# 100:	learn: 899.5811881	total: 23.6s	remaining: 46.5s
# 200:	learn: 844.2929752	total: 46.8s	remaining: 23s
# 299:	learn: 795.8067894	total: 1m 9s	remaining: 0us
# 0:	learn: 962.8894239	total: 130ms	remaining: 39s
# 100:	learn: 900.4169626	total: 23.1s	remaining: 45.5s
# 200:	learn: 844.9797777	total: 46s	remaining: 22.7s
# 299:	learn: 796.4329607	total: 1m 8s	remaining: 0us
# 0:	learn: 963.0451314	total: 189ms	remaining: 56.4s
# 100:	learn: 900.4289388	total: 23s	remaining: 45.4s
# 200:	learn: 844.9076855	total: 45.7s	remaining: 22.5s
# 299:	learn: 796.1611484	total: 1m 8s	remaining: 0us
# 0:	learn: 961.9738797	total: 126ms	remaining: 37.8s
# 100:	learn: 899.6621875	total: 23.3s	remaining: 45.8s
# 200:	learn: 844.3587273	total: 46.2s	remaining: 22.8s
# 299:	learn: 795.8566335	total: 1m 9s	remaining: 0us
# 0:	learn: 902.4476126	total: 45.3ms	remaining: 13.5s
# 100:	learn: 419.2777179	total: 12.8s	remaining: 25.2s
# 200:	learn: 401.3701453	total: 25.9s	remaining: 12.8s
# 299:	learn: 392.2781147	total: 38.7s	remaining: 0us
# 0:	learn: 902.2760969	total: 17.8ms	remaining: 5.33s
# 100:	learn: 418.5575659	total: 13s	remaining: 25.5s
# 200:	learn: 401.6931320	total: 25.7s	remaining: 12.7s
# 299:	learn: 392.7865449	total: 38.6s	remaining: 0us
# 0:	learn: 902.8432817	total: 18.4ms	remaining: 5.5s
# 100:	learn: 419.3144891	total: 12.9s	remaining: 25.3s
# 200:	learn: 401.3334618	total: 25.7s	remaining: 12.7s
# 299:	learn: 392.7477201	total: 38.3s	remaining: 0us
# 0:	learn: 903.0473659	total: 100ms	remaining: 29.9s
# 100:	learn: 417.0132185	total: 12.9s	remaining: 25.5s
# 200:	learn: 400.0297038	total: 25.5s	remaining: 12.5s
# 299:	learn: 391.3376272	total: 38s	remaining: 0us
# 0:	learn: 901.8122129	total: 73.4ms	remaining: 21.9s
# 100:	learn: 419.6888305	total: 12.8s	remaining: 25.3s
# 200:	learn: 402.3144272	total: 25.8s	remaining: 12.7s
# 299:	learn: 393.0942709	total: 38.5s	remaining: 0us
# 0:	learn: 898.4833314	total: 82.5ms	remaining: 24.7s
# 100:	learn: 398.0948619	total: 18.8s	remaining: 37.1s
# 200:	learn: 379.3552365	total: 37.3s	remaining: 18.4s
# 299:	learn: 367.8877894	total: 55.7s	remaining: 0us
# 0:	learn: 898.2378594	total: 107ms	remaining: 32.1s
# 100:	learn: 398.1100186	total: 18.6s	remaining: 36.7s
# 200:	learn: 379.3193184	total: 37.3s	remaining: 18.4s
# 299:	learn: 367.9500503	total: 55.6s	remaining: 0us
# 0:	learn: 898.8423157	total: 95.9ms	remaining: 28.7s
# 100:	learn: 397.8673685	total: 18.5s	remaining: 36.5s
# 200:	learn: 380.0803895	total: 36.8s	remaining: 18.1s
# 299:	learn: 367.6596506	total: 55.1s	remaining: 0us
# 0:	learn: 899.0235549	total: 73.4ms	remaining: 21.9s
# 100:	learn: 396.6515571	total: 18.1s	remaining: 35.7s
# 200:	learn: 378.0315140	total: 36s	remaining: 17.8s
# 299:	learn: 366.6957530	total: 53.7s	remaining: 0us
# 0:	learn: 897.8875681	total: 91.3ms	remaining: 27.3s
# 100:	learn: 398.2909520	total: 18.4s	remaining: 36.3s
# 200:	learn: 379.3408400	total: 36.8s	remaining: 18.1s
# 299:	learn: 367.2642250	total: 54.9s	remaining: 0us
# 0:	learn: 962.2917362	total: 47.6ms	remaining: 14.2s
# 100:	learn: 900.8131944	total: 19.2s	remaining: 37.8s
# 200:	learn: 846.5218284	total: 38.1s	remaining: 18.8s
# 299:	learn: 798.9209792	total: 56.9s	remaining: 0us
# 0:	learn: 961.8979390	total: 101ms	remaining: 30.1s
# 100:	learn: 900.4659837	total: 19.1s	remaining: 37.7s
# 200:	learn: 846.1762698	total: 38.4s	remaining: 18.9s
# 299:	learn: 798.6771605	total: 57.3s	remaining: 0us
# 0:	learn: 962.8964741	total: 114ms	remaining: 34.1s
# 100:	learn: 901.3728955	total: 19s	remaining: 37.5s
# 200:	learn: 847.0509393	total: 37.8s	remaining: 18.6s
# 299:	learn: 799.4643925	total: 56.5s	remaining: 0us
# 0:	learn: 963.0526977	total: 103ms	remaining: 30.7s
# 100:	learn: 901.4372686	total: 19s	remaining: 37.5s
# 200:	learn: 846.8627473	total: 38.1s	remaining: 18.8s
# 299:	learn: 799.0717951	total: 56.9s	remaining: 0us
# 0:	learn: 961.9814883	total: 50.4ms	remaining: 15.1s
# 100:	learn: 900.5747104	total: 18.7s	remaining: 36.8s
# 200:	learn: 846.2880266	total: 37.5s	remaining: 18.5s
# 299:	learn: 798.7908285	total: 56s	remaining: 0us
# 0:	learn: 962.3307155	total: 42.8ms	remaining: 12.8s
# 100:	learn: 905.8229330	total: 13.3s	remaining: 26.2s
# 200:	learn: 855.6832847	total: 26.5s	remaining: 13.1s
# 299:	learn: 811.7895623	total: 39.5s	remaining: 0us
# 0:	learn: 961.9376556	total: 93ms	remaining: 27.8s
# 100:	learn: 905.3697166	total: 13.3s	remaining: 26.3s
# 200:	learn: 855.3534841	total: 26.7s	remaining: 13.1s
# 299:	learn: 811.5825689	total: 39.9s	remaining: 0us
# 0:	learn: 962.9357989	total: 66.3ms	remaining: 19.8s
# 100:	learn: 906.3351382	total: 13.3s	remaining: 26.2s
# 200:	learn: 856.1182656	total: 26.6s	remaining: 13.1s
# 299:	learn: 812.1490147	total: 39.7s	remaining: 0us
# 0:	learn: 963.0922598	total: 64.1ms	remaining: 19.2s
# 100:	learn: 906.3292944	total: 14.9s	remaining: 29.3s
# 200:	learn: 855.9785522	total: 28.2s	remaining: 13.9s
# 299:	learn: 811.9704249	total: 41.6s	remaining: 0us
# 0:	learn: 962.0200657	total: 17.8ms	remaining: 5.33s
# 100:	learn: 905.5011881	total: 13.4s	remaining: 26.3s
# 200:	learn: 855.3920370	total: 26.7s	remaining: 13.2s
# 299:	learn: 811.5370027	total: 40s	remaining: 0us
# 0:	learn: 930.8571710	total: 25.7ms	remaining: 7.68s
# 100:	learn: 427.0373256	total: 16.3s	remaining: 32s
# 200:	learn: 404.8427621	total: 32.1s	remaining: 15.8s
# 299:	learn: 394.3710799	total: 48s	remaining: 0us
# 0:	learn: 930.5414649	total: 23.3ms	remaining: 6.95s
# 100:	learn: 427.5254342	total: 16.4s	remaining: 32.2s
# 200:	learn: 405.1479082	total: 32.5s	remaining: 16s
# 299:	learn: 394.6783561	total: 48.5s	remaining: 0us
# 0:	learn: 931.3932715	total: 61.6ms	remaining: 18.4s
# 100:	learn: 426.6807191	total: 16.6s	remaining: 32.7s
# 200:	learn: 404.8620368	total: 32.7s	remaining: 16.1s
# 299:	learn: 394.8483131	total: 48.7s	remaining: 0us
# 0:	learn: 931.5121639	total: 37.3ms	remaining: 11.1s
# 100:	learn: 425.0388198	total: 16.5s	remaining: 32.4s
# 200:	learn: 403.3851883	total: 32.3s	remaining: 15.9s
# 299:	learn: 393.2227365	total: 48s	remaining: 0us
# 0:	learn: 930.4170009	total: 81.6ms	remaining: 24.4s
# 100:	learn: 425.8001356	total: 16.5s	remaining: 32.6s
# 200:	learn: 404.2528770	total: 32.7s	remaining: 16.1s
# 299:	learn: 394.0935806	total: 48.6s	remaining: 0us
# 0:	learn: 900.7320312	total: 36.8ms	remaining: 11s
# 100:	learn: 411.5856342	total: 14.3s	remaining: 28.1s
# 200:	learn: 394.2702685	total: 28.7s	remaining: 14.1s
# 299:	learn: 384.7042580	total: 42.9s	remaining: 0us
# 0:	learn: 900.5314373	total: 87.5ms	remaining: 26.2s
# 100:	learn: 412.1992987	total: 14.6s	remaining: 28.8s
# 200:	learn: 393.9952759	total: 29.1s	remaining: 14.3s
# 299:	learn: 384.5559544	total: 43.4s	remaining: 0us
# 0:	learn: 901.1123069	total: 19.9ms	remaining: 5.95s
# 100:	learn: 411.6444059	total: 14.4s	remaining: 28.5s
# 200:	learn: 394.2548895	total: 29.7s	remaining: 14.6s
# 299:	learn: 384.7742089	total: 44.6s	remaining: 0us
# 0:	learn: 901.2955375	total: 39.2ms	remaining: 11.7s
# 100:	learn: 411.0934921	total: 14.3s	remaining: 28.1s
# 200:	learn: 393.3327172	total: 28.5s	remaining: 14s
# 299:	learn: 384.0026224	total: 42.8s	remaining: 0us
# 0:	learn: 900.1046058	total: 61.9ms	remaining: 18.5s
# 100:	learn: 412.0517915	total: 14.5s	remaining: 28.6s
# 200:	learn: 394.5200554	total: 28.9s	remaining: 14.3s
# 299:	learn: 384.8583191	total: 43.2s	remaining: 0us
# 0:	learn: 899.3517756	total: 110ms	remaining: 32.9s
# 100:	learn: 404.7868111	total: 16.2s	remaining: 31.9s
# 200:	learn: 387.4554426	total: 32.5s	remaining: 16s
# 299:	learn: 376.5291485	total: 48.4s	remaining: 0us
# 0:	learn: 899.1165937	total: 59.7ms	remaining: 17.9s
# 100:	learn: 405.0869569	total: 16.3s	remaining: 32.1s
# 200:	learn: 387.4797711	total: 32.5s	remaining: 16s
# 299:	learn: 377.0893401	total: 49s	remaining: 0us
# 0:	learn: 899.8166752	total: 107ms	remaining: 32.1s
# 100:	learn: 405.1486417	total: 16.3s	remaining: 32.2s
# 200:	learn: 387.3007428	total: 32.4s	remaining: 15.9s
# 299:	learn: 376.7713262	total: 48.4s	remaining: 0us
# 0:	learn: 899.8977594	total: 49.4ms	remaining: 14.8s
# 100:	learn: 403.5673788	total: 16.5s	remaining: 32.4s
# 200:	learn: 386.1146198	total: 32.7s	remaining: 16.1s
# 299:	learn: 375.7766309	total: 48.9s	remaining: 0us
# 0:	learn: 898.7763244	total: 100ms	remaining: 29.9s
# 100:	learn: 404.9227170	total: 16.2s	remaining: 32s
# 200:	learn: 386.8641853	total: 32.5s	remaining: 16s
# 299:	learn: 376.2966616	total: 48.4s	remaining: 0us
# 0:	learn: 898.8298849	total: 201ms	remaining: 1m
# 100:	learn: 398.5849617	total: 21.3s	remaining: 42.1s
# 200:	learn: 380.5148440	total: 42.9s	remaining: 21.1s
# 299:	learn: 369.3954745	total: 1m 3s	remaining: 0us
# Качество модели CatBoost на валидационной выборке (корень из средней квадратичной ошибки): 380.6169351197825

# %% [markdown]
# ### LightGBM

# %%
model_lgb = lgb.LGBMRegressor(random_state=12345)
parameters_lgb = {'depth': range(6, 11),
                 'learning_rate': [0.001, 0.01, 0.05, 0.1],
                 'n_estimators': range(100, 501, 50)}
search_lgb = RandomizedSearchCV(model_lgb, parameters_lgb, cv = 5, n_jobs = -1, random_state = 12345)
search_lgb.fit(features_train, target_train)
best_lgb = search_lgb.best_estimator_
predict_lgb_valid = best_lgb.predict(features_valid)
rmse_lgb_valid = mean_squared_error(target_valid, predict_lgb_valid)**0.5
print('Качество модели LighGBM на валидационной выборке (корень из средней квадратичной ошибки):', rmse_lgb_valid)
# Out:
# Качество модели LighGBM на валидационной выборке (корень из средней квадратичной ошибки): 378.0037006957832

# %% [markdown]
# ### XGBoost

# %%
model_xgb = xgb.XGBRegressor(random_state = 12345)
parameters_xgb = {'booster': ['gbtree', 'gblinear'], 
                  'max_depth':range(4, 11), 
                  'learning_rate': [0.01, 0.05, 0.1, 0.001, 0.5], 
                  'n_estimators':range(100, 501, 50)}
search_xgb = RandomizedSearchCV(model_xgb, parameters_xgb, cv = 5, n_jobs = -1, random_state = 12345)
search_xgb.fit(features_train, target_train)
best_xgb = search_xgb.best_estimator_
predict_xgb_valid = best_xgb.predict(features_valid)
rmse_xgb_valid = mean_squared_error(target_valid, predict_xgb_valid)**0.5
print('Качество модели XGBoost на валидационной выборке (корень из средней квадратичной ошибки):', rmse_xgb_valid)
# Out:
# [12:42:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:43:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:43:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:44:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:44:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:45:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:48:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:51:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:54:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:57:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:00:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:03:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:06:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:09:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:11:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:14:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:16:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:18:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:19:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:21:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:22:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:23:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:23:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:24:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:24:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:25:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:25:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:25:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:25:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:25:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:25:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:26:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:27:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:28:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:29:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:30:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:30:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:31:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:31:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:31:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:32:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:32:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:32:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:33:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:33:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:34:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:34:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:34:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:34:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:35:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:35:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Качество модели XGBoost на валидационной выборке (корень из средней квадратичной ошибки): 369.8280035424082

# %% [markdown]
# # 3. Анализ моделей

# %% [markdown]
# ### CatBoost

# %%
# %%time
start_cb_fit = time.time()
best_cb.fit(features_train, target_train, verbose = 100)
end_cb_fit = time.time()
time_cb_fit = end_cb_fit - start_cb_fit
start_cb_predict = time.time()
predict_cb_test = best_cb.predict(features_test)
end_cb_predict = time.time()
time_cb_predict = end_cb_predict - start_cb_predict
rmse_cb_test = mean_squared_error(target_test, predict_cb_test)**0.5
print('Качество модели CatBoost на тестовой выборке (корень из средней квадратичной ошибки):', rmse_cb_test)
# Out:
# 0:	learn: 898.8298849	total: 133ms	remaining: 39.7s
# 100:	learn: 398.5849617	total: 22.4s	remaining: 44.1s
# 200:	learn: 380.5148440	total: 45.1s	remaining: 22.2s
# 299:	learn: 369.3954745	total: 1m 7s	remaining: 0us
# Качество модели CatBoost на тестовой выборке (корень из средней квадратичной ошибки): 388.10319768211525
# CPU times: user 59.8 s, sys: 8.55 s, total: 1min 8s
# Wall time: 1min 12s

# %% [markdown]
# ### LightGBM

# %%
# %%time
start_lgb_fit = time.time()
best_lgb.fit(features_train, target_train)
end_lgb_fit = time.time()
time_lgb_fit = end_lgb_fit - start_lgb_fit
start_lgb_predict = time.time()
predict_lgb_test = best_lgb.predict(features_test)
end_lgb_predict = time.time()
time_lgb_predict = end_lgb_predict - start_lgb_predict

rmse_lgb_test = mean_squared_error(target_test, predict_lgb_test)**0.5
print('Качество модели CatBoost (корень из средней квадратичной ошибки):', rmse_lgb_test)
# Out:
# Качество модели CatBoost (корень из средней квадратичной ошибки): 384.4394656444861
# CPU times: user 10.6 s, sys: 17.9 ms, total: 10.6 s
# Wall time: 11.3 s

# %% [markdown]
# ### XGBoost

# %%
# %%time
start_xgb_fit = time.time()
best_xgb.fit(features_train, target_train)
end_xgb_fit = time.time()
time_xgb_fit = end_xgb_fit - start_xgb_fit
start_xgb_predict = time.time()
predict_xgb_test = best_xgb.predict(features_test)
end_xgb_predict = time.time()
time_xgb_predict = end_xgb_predict - start_xgb_predict
rmse_xgb_test = mean_squared_error(target_test, predict_xgb_test)**0.5
print('Качество модели XGBoost (корень из средней квадратичной ошибки):', rmse_xgb_test)
# Out:
# [13:38:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Качество модели XGBoost (корень из средней квадратичной ошибки): 377.7249628896845
# CPU times: user 2min 4s, sys: 0 ns, total: 2min 4s
# Wall time: 2min 9s

# %%
data_final = [['CatBoost', rmse_cb_test, time_cb_fit, time_cb_predict], 
              ['LightGBM', rmse_lgb_test, time_lgb_fit, time_lgb_predict], 
              ['XGBoost', rmse_xgb_test, time_xgb_fit, time_xgb_predict]]
columns_final = ['model', 'rmse','time_fit', 'time_predict']
table_final = pd.DataFrame(data = data_final, columns = columns_final)
table_final
# Out:
#       model        rmse    time_fit  time_predict
# 0  CatBoost  388.103198   72.382090      0.195629
# 1  LightGBM  384.439466    8.128227      3.125223
# 2   XGBoost  377.724963  126.155531      2.971491

# %% [markdown]
# # Вывод

# %% [markdown]
# Из полученных результатов и технического задания, можно сделать вывод, что наиболее подходящей библиотекой градиентного бустинга для решения поставленной задачи является LigthGBM, так как модель обладает близким значением RMSE к остальным моделям и наименьшим временем обучения и предсказания.

# %% [markdown]
# ## Чек-лист проверки

# %% [markdown]
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Выполнена загрузка и подготовка данных
# - [x]  Выполнено обучение моделей
# - [x]  Есть анализ скорости работы и качества моделей
